// %%
const validActions = {
  mo: 'shortcut for the command module',
  module: 'create module',
  ctrl: 'shortcut for the command controller',
  controller: 'create controller',
  srv: 'shortcut for the command service',
  service: 'create service',
  all: 'create all (module, controller, service, dto)',
  dto: 'create dto',
  dtos: 'create dto',
}

// %%
validActions.hasOwnProperty('moa')
// Out:
// false
